# %%
# %pip install roboflow 
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Get Dataset

# %%
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="0Cf9Ds1YjrB4nAE4Xwrx")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import shutil

# %%
shutil.move("tennis-ball-detection-6/train", 
            "tennis-ball-detection-6/tenis-ball-detection-6/train",
            )

shutil.move("tennis-ball-detection-6/test", 
            "tennis-ball-detection-6/tenis-ball-detection-6/test",
            )

shutil.move("tennis-ball-detection-6/valid", 
            "tennis-ball-detection-6/tenis-ball-detection-6/valid",
            )

shutil.move("tennis-ball-detection-6/test", 
            "tennis-ball-detection-6/tenis-ball-detection-6/test",
            )

shutil.move("tennis-ball-detection-6/valid", 
            "tennis-ball-detection-6/tenis-ball-detection-6/valid",
            )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\shutil.py:853, in move(src, dst, copy_function)
#     852 try:
# --> 853     os.rename(src, real_dst)
#     854 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'tennis-ball-detection-6/train' -> 'tennis-ball-detection-6/tenis-ball-detection-6/train\\train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 shutil.move("tennis-ball-detection-6/train",
#       2             "tennis-ball-detection-6/tenis-ball-detection-6/train",
#       3             )
#       5 shutil.move("tennis-ball-detection-6/test",
# ...
